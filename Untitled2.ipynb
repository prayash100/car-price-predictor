# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("practice_21.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area(sqft)')
plt.ylabel('price(us$)')
plt.scatter(df.area,df.price,color='red',marker='+')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
reg.predict(np.array([[5000]]))
# Out:
# C:\Users\PRATYUSH\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
# %matplotlib inline
plt.xlabel('area(sqft)')
plt.ylabel('price(us$)')
plt.scatter(df.area,df.price,color='red',marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')

# %%
d=pd.read_csv("Book-2.csv")
d.head(3)
# Out:
#    area
# 0   500
# 1  1000
# 2  1500

# %%
p=reg.predict(d)
# Out:
# [ 248510.2739726   316404.10958904  384297.94520548 1217626.88356164
#  1193999.82876712 1495584.24657534  679500.34246575  949582.02054795
#   948767.29452055  952569.34931507 6393852.9109589 ]

# %%
d['prices']=p

# %%
d
# Out:
#      area        prices
# 0     500  2.485103e+05
# 1    1000  3.164041e+05
# 2    1500  3.842979e+05
# 3    7637  1.217627e+06
# 4    7463  1.194000e+06
# 5    9684  1.495584e+06
# 6    3674  6.795003e+05
# 7    5663  9.495820e+05
# 8    5657  9.487673e+05
# 9    5685  9.525693e+05
# 10  45757  6.393853e+06

# %%
d.to_csv("prediction.csv",index=False)
